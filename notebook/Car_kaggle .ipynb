# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\Загрузки\manufacturers.csv")

# %%
df
# Out:
#               name          twitter twitter_tweets twitter_followers  \
# 0              BMW             /bmw          43.1K              2.5M
# 1       Ford Motor            /ford          49.1K              1.5M
# 2   General Motors              /GM          20.8K            801.1K
# 3            Honda           /honda         206.8K              1.2M
# 4          Hyundai  /Hyundai_Global           9054            338.4K
# 5    Mercedes-Benz    /mercedesbenz          73.2K              4.0M
# 6           Nissan     /NissanMotor           5818            211.7K
# 7          Porsche         /Porsche           5401              2.2M
# 8       SAIC Motor                x              x                 x
# 9       Stellantis      /stellantis           5145             92.4K
# 10           Tesla           /Tesla           8218             20.5M
# 11          Toyota          /toyota          58.8K            933.6K
# 12      Volkswagen              /vw          35.2K            711.8K
# ...
