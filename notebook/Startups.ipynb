# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\Startups.csv")

# %%
df.columns.tolist()
# Out:
# ['Company',
#  'Satus',
#  'Year Founded',
#  'Mapping Location',
#  'Description',
#  'Categories',
#  'Founders',
#  'Y Combinator Year',
#  'Y Combinator Session',
#  'Investors',
#  'Amounts raised in different funding rounds',
#  'Office Address',
#  'Headquarters (City)',
#  'Headquarters (US State)',
#  'Headquarters (Country)',
#  'Logo',
#  'Seed-DB / Mattermark Profile',
#  'Crunchbase / Angel List Profile',
#  'Website']

# %%
df1 = df.drop(columns=['Logo',
 'Seed-DB / Mattermark Profile',
 'Crunchbase / Angel List Profile',
 'Website'])

# %%
df1.sort_values(by ='Y Combinator Year',ascending=False)
# Out:
#              Company      Satus  Year Founded  \
# 344    Helion Energy  Operating           NaN
# 238          Aptible  Operating           NaN
# 518  The Dating Ring  Operating           NaN
# 517        TerrAvion  Operating           NaN
# 244         Backpack  Operating           NaN
# ..               ...        ...           ...
# 277       ClickFacts  Operating           NaN
# 672            Loopt     Exited        2005.0
# 404           Memamp       Dead           NaN
# 483          Simmery       Dead           NaN
# 317        Firecrawl     Exited        2005.0
#
#                      Mapping Location  \
# 344     Redmond WA - Washington - USA
# 238  San Francisco - California - USA
# 518                               NaN
# 517      Livermore - California - USA
# 244  San Francisco - California - USA
# ..                                ...
# 277  San Francisco - California - USA
# 672  Mountain View - California - USA
# 404                               NaN
# ...

# %%
Используя функцию регулярного выражения по вытаскивать информацию из текста, для тренировки  и для понимания что быстрее работает построить графики matplotlib,seaborn,plotly
